# %%
#Instituto Superior Politécnico de Córdoba - Tecnicatura Superior en Ciencia de Datos e Inteligencia Artificial.
#Código Practica profezionalizante 1 - Caso de Estudio Casos de Covid - Ciudad de Córdoba - Provincia de Córdoba
#Grupo Formado por: Carina Giovine - Octavio Gómez - Eduardo Herrero Rivero

# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient('localhost',27017)
db = client['CasosCOVID19Cba']
#creo la colección del mismo nombre
collection=db['CasosCOVID19Cba']
#cargo los datos del archivo csv
df=pd.read_csv('D:\PProfezionalizante1\CCCba.csv')
data=df.to_dict('records')
#ahora inserto
collection.insert_many(data)
print("La información ha sido cargada exitosamente")
# Out:
# La información ha sido cargada exitosamente

# %%
print(df)
# Out:
#          Fecha  Casos registrados Ciudad de Córdoba (acumulado)  \
# 0    25/3/2020                                               21
# 1    26/3/2020                                               22
# 2    28/3/2020                                               24
# 3    29/3/2020                                               30
# 4    30/3/2020                                               30
# ..         ...                                              ...
# 479  18/7/2021                                           199482
# 480  19/7/2021                                           199720
# 481  20/7/2021                                           200028
# 482  21/7/2021                                           200867
# 483  22/7/2021                                           201937
#
#      Casos registrados Provincia de Córdoba (acumulado)  \
# 0                                                   49
# 1                                                   52
# ...

# %%
df.head()
# Out:
#        Fecha  Casos registrados Ciudad de Córdoba (acumulado)  \
# 0  25/3/2020                                               21
# 1  26/3/2020                                               22
# 2  28/3/2020                                               24
# 3  29/3/2020                                               30
# 4  30/3/2020                                               30
#
#    Casos registrados Provincia de Córdoba (acumulado)  \
# 0                                                 49
# 1                                                 52
# 2                                                 56
# 3                                                 73
# 4                                                 80
#
#    Fallecidos Provincia de Córdoba (acumulado)  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# ...

# %%
df.columns
# Out:
# Index(['Fecha', 'Casos registrados Ciudad de Córdoba (acumulado)',
#        'Casos registrados Provincia de Córdoba (acumulado)',
#        'Fallecidos Provincia de Córdoba (acumulado)',
#        'Nuevos casos registrados Ciudad de Córdoba',
#        'Nuevos casos registrados Provincia de Córdoba'],
#       dtype='object')

# %%
df.plot()

# %%
#muestra las últimas 5 líneas 
df.tail(5)
# Out:
#          Fecha  Casos registrados Ciudad de Córdoba (acumulado)  \
# 479  18/7/2021                                           199482
# 480  19/7/2021                                           199720
# 481  20/7/2021                                           200028
# 482  21/7/2021                                           200867
# 483  22/7/2021                                           201937
#
#      Casos registrados Provincia de Córdoba (acumulado)  \
# 479                                             445141
# 480                                             446235
# 481                                             447580
# 482                                             449515
# 483                                             451732
#
#      Fallecidos Provincia de Córdoba (acumulado)  \
# 479                                         5862
# 480                                         5893
# 481                                         5927
# ...

# %%
reporte=df.describe()
reporte
# Out:
#        Casos registrados Ciudad de Córdoba (acumulado)  \
# count                                       484.000000
# mean                                      54543.863636
# std                                       57098.279392
# min                                          21.000000
# 25%                                         795.000000
# 50%                                       51724.500000
# 75%                                       75624.500000
# max                                      201937.000000
#
#        Casos registrados Provincia de Córdoba (acumulado)  \
# count                                         484.000000
# mean                                       119941.578512
# std                                        126383.565299
# min                                            49.000000
# 25%                                          1669.500000
# 50%                                        109389.500000
# 75%                                        173787.250000
# ...

# %%
#roto la tabla de los datos con la transpuesta
reporte.T
# Out:
#                                                     count           mean  \
# Casos registrados Ciudad de Córdoba (acumulado)     484.0   54543.863636
# Casos registrados Provincia de Córdoba (acumulado)  484.0  119941.578512
# Fallecidos Provincia de Córdoba (acumulado)         484.0    1814.427686
#
#                                                               std   min  \
# Casos registrados Ciudad de Córdoba (acumulado)      57098.279392  21.0
# Casos registrados Provincia de Córdoba (acumulado)  126383.565299  49.0
# Fallecidos Provincia de Córdoba (acumulado)           1718.162758   0.0
#
#                                                        25%       50%  \
# Casos registrados Ciudad de Córdoba (acumulado)      795.0   51724.5
# Casos registrados Provincia de Córdoba (acumulado)  1669.5  109389.5
# Fallecidos Provincia de Córdoba (acumulado)           43.0    1796.5
#
#                                                           75%       max
# ...

# %%
#consultas una vez creada la base de datos, conecto

# %%
import pymongo
client = pymongo.MongoClient('localhost',27017)
print(client.list_database_names())
db = client['CasosCOVID19Cba']
# Out:
# ['CasosCOVID19Cba', 'admin', 'config', 'local', 'prueba_python', 'weatherHistory']

# %%
db.CasosCOVID19Cba.count()
# Out:
# <ipython-input-15-69d82dd90aed>:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   db.CasosCOVID19Cba.count()
# 484

# %%
print(db.list_collection_names())
# Out:
# ['CasosCOVID19Cba']

# %%
#cierro la conexion a Mongodb
client.close()

# %%
#conecto a Mongo y con la Base de Datos CasosCOVID19Cba, collection CasosCOVID19Cba
import pymongo
mongoClient = pymongo.MongoClient('localhost',27017)
db = mongoClient.CasosCOVID19Cba
col = db.CasosCOVID19Cba
#mydb = mongoClient["CasosCOVID19Cba"]
#mycol = mydb["CasosCOVID19Cba"]

# %%
db.CasosCOVID19Cba.count()
# Out:
# <ipython-input-26-69d82dd90aed>:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   db.CasosCOVID19Cba.count()
# 484

# %%
db.list_collection_names()
# Out:
# ['CasosCOVID19Cba']

# %%
cursor = collection.find()
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('6105b7d927ef8a4df1de80f6'), 'Fecha': '25/3/2020', 'Casos registrados Ciudad de Córdoba (acumulado)': 21, 'Casos registrados Provincia de Córdoba (acumulado)': 49, 'Fallecidos Provincia de Córdoba (acumulado)': 0, 'Nuevos casos registrados Ciudad de Córdoba': nan, 'Nuevos casos registrados Provincia de Córdoba': nan}
# {'_id': ObjectId('6105b7d927ef8a4df1de80f7'), 'Fecha': '26/3/2020', 'Casos registrados Ciudad de Córdoba (acumulado)': 22, 'Casos registrados Provincia de Córdoba (acumulado)': 52, 'Fallecidos Provincia de Córdoba (acumulado)': 0, 'Nuevos casos registrados Ciudad de Córdoba': '1', 'Nuevos casos registrados Provincia de Córdoba': '3'}
# ...

# %%
print(collection)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'CasosCOVID19Cba'), 'CasosCOVID19Cba')

# %%
db.CasosCOVID19Cba.find(({'Fecha': '20/7/2021'}))

# %%
#Cerrar la conexion
mongoClient.close()
